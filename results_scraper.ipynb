# %% [markdown]
# ## Import Dependencies

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Run the webscraper

# %%
# set up the driver
service = ChromeService(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome("/Users/macdkw/Downloads/chromedriver")

# Navigate to the page
def home():
    driver.get("https://www.texasmusicforms.com/csrrptUILpublic.asp")

# get results button function
def click_results_button():
    get_results_button = driver.find_element(by=By.CLASS_NAME, value="btn-success")
    get_results_button.click()


# "Search again" button function
def click_search_button():
    search_again_button = driver.find_element(by=By.NAME, value="chan")
    search_again_button.click()
    driver.implicitly_wait(10)

# find the drop down menus and fill them out
def form_completer(year, region, contest_item):
    year_menu = driver.find_element(by=By.NAME, value="yr")
    region_menu = driver.find_element(by=By.NAME, value="reg")
    event_menu = driver.find_element(by=By.NAME, value="ev")
    year_menu.send_keys(year)
    region_menu.send_keys(f"Region {region}")
    event_menu.send_keys("Band")

    # find the hidden drop down menu, and collect its contents
    contest_menu = driver.find_element(by=By.NAME, value="cn")
    contest_menu_contents = contest_menu.find_elements(by=By.TAG_NAME, value="option")
    contest_menu_length = len(contest_menu_contents)
    contest_menu.send_keys(contest_menu_contents[contest_item].text)


# scrape the data
def scraper_loop():
    # make sure that were seeing all results, not just the top 20
    show_all_button = driver.find_element(by=By.NAME, value="DataTables_Table_0_length")
    show_all_button.send_keys("All")
    # get the table
    table = driver.find_elements(by=By.TAG_NAME, value="tbody")[1]
    table_rows = table.find_elements(by=By.TAG_NAME, value="tr")
    # loop through table contents
    for row in table_rows:
        cells = row.find_elements(by=By.TAG_NAME, value="td")
        column_content = []
        for cell in cells:
            cell_content_full = cell.text
            cell_content = cell_content_full.split("\n")
            for i in cell_content:
                column_content.append(i)
            #column_content.append(cell_content)
        row_content.append(column_content)

# convert to dataframe
def convert_to_dataframe():
    df = pd.DataFrame(row_content)
    if len(df.columns) == 21:
        df.columns = columns_21
    elif len(df.columns) == 22:
        df.columns = columns_22
    # export to csv
    df.to_csv(f"full_run/texas_music_forms_{year}_{region}_{contest_item}_band.csv")

columns_21 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3']

columns_22 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3', 'oops']

row_content = []

# Define year and region variables
year = 2005
region = 0

for y in range(2005, 2023):
    for r in range(0, 33):
        try:
            contest_item = 1
            region = region + 1
            for i in range(1, 15):
                try:
                    home()
                    form_completer(year, region, contest_item)
                    click_results_button()
                    scraper_loop()
                    convert_to_dataframe()
                    contest_item = contest_item + 1
                    row_content = []
                except:
                    print(f"{year}, {region}, {contest_item}")
                    break
        except:
            break
    year = year + 1
    region = 0

# %%
### Define column headers for csv export
columns_21 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3']
columns_22 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3', 'oops']

# %% [markdown]
# ## Group the CSVs together, and fix rows with Accompanist error

# %%
# list of merged files returned
files = glob.glob("full_run/*.csv")

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df = pd.DataFrame(df)

# drop unnamed column
df.drop(columns=['Unnamed: 0'], inplace=True)

# select rows with acc column 
oops_df = df[df['oops'].notnull()]

# delete the acc columns and fix column names
oops_fix_df = oops_df.drop(columns=['Conference'])
oops_fix_df.columns = columns_21

# drop acc rows from df
df = df.loc[df['oops'].isnull() == True]

# add fixed df to df
df = pd.concat([df, oops_fix_df], ignore_index=True)

# drop oops column
df.drop(columns=['oops'], inplace=True)

# %% [markdown]
# ## Clean the data further

# %%
# drop duplicate rows
df_clean = df
df_clean.drop_duplicates(keep='first', inplace=True)
df_clean.sort_values(by=['Classification', 'Year'], inplace=True)
df_clean
# Out:
#                    Event                       School               TEA  \
# 10728   100-Concert Band               Woodville High              TEA:
# 11455   100-Concert Band         New Deal High School              TEA:
# 12859   100-Concert Band         Progreso High School              TEA:
# 13480   100-Concert Band                     Bangs HS              TEA:
# 15386   100-Concert Band             Alicia R. Chacon              TEA:
# ...                  ...                          ...               ...
# 34426   100-Concert Band    Warren Junior High School              TEA:
# 45355   100-Concert Band                   McCamey MS              TEA:
# 59639   100-Concert Band                    Alpine MS   TEA: 022 901041
# 59894   100-Concert Band   Lake Air Montessori Magnet       TEA: 161914
# 30446   100-Concert Band                     Eastland              TEA:
#
#              City                                      Directors Conference  \
# 10728   Woodville                                      Lou Ellis         AA
# 11455    New Deal                        James Nance / Kay Nance          A
# 12859    Progreso                                    James Yates        AAA
# 13480       Bangs                 Tommy Perkins / Charla Bretzke         AA
# 15386     El Paso   Jose Barriga / Salvador Melendez, Louie Nava          C
# ...           ...                                            ...        ...
# 34426      Warren                  Carl Hooper / Russell Hopkins        AAA
# 45355     McCamey                  Shawna Torres / German Torres          C
# 59639      Alpine                                    Marina Azar          C
# 59894        Waco           Todd Modgling / Stephanie Fernihough          C
# 30446    Eastland    Stephen Cox / Terry Everts, Dillon Phillips         AA
#
#       Classification  Year      ID Stage Judge 1  ... Stage Judge 3  \
# 10728                 2009   46343             2  ...             2
# 11455                 2009   45190             2  ...             1
# 12859                 2009   48134             3  ...             2
# 13480                 2009   43637             1  ...             1
# 15386                 2010   59515             1  ...             1
# ...              ...   ...     ...           ...  ...           ...
# 34426      Varsity C  2016  116407             4  ...             4
# 45355      Varsity C  2018  129652             2  ...             2
# 59639      Varsity C  2022  172064             1  ...             1
# 59894      Varsity C  2022  175313             2  ...             1
# 30446      Varsity C  2014   91726             2  ...             2
#
#       Stage Final SR Judge 1 SR Judge 2 SR Judge 3 SR Final Award  \
# 10728           2          1          1          1        1     1
# 11455           2          1          1          1        1     1
# 12859           2          2          2          2        2
# 13480           1          1          1          1        1     A
# 15386           1          2          1          1        1     C
# ...           ...        ...        ...        ...      ...   ...
# 34426           4          2          1          1        1     2
# 45355           2          1          2          1        1     2
# 59639           1          1          1          1        1     C
# 59894           2          1          2          1        1     2
# 30446           2          1          2          1        1     2
#
#                                            Selection 1  \
# 10728   Under The Double Eagle - March (Wagner/Glover)
# 11455                 La Fiesta Brava (John Edmondson)
# 12859                    Portrait of a Clown (Ticheli)
# 13480                        Monterey March (LaPlante)
# 15386                      Lexington March (Edmondson)
# ...                                                ...
# 34426             Swashbuckler's march (Mark Williams)
# 45355                      Forward March (Paul Murtha)
# 59639               Independentia March (Matt Conaway)
# 59894             Spirit of America March (Ken Harris)
# 30446         The Big Circus March ( Robert E. Foster)
#
#                                              Selection 2  \
# 10728                      A Childhood Hymn  (Holsinger)
# 11455                       Cumberland Cross  (Strommen)
# 12859                                Prospect (La Plant)
# 13480   Two British Folk Songs  (Anon. or Trad./Del B...
# 15386                          Voodoo Dance  (del Borgo)
# ...                                                  ...
# 34426              Courtlandt County Festival  (Owens/ )
# 45355                                Majestica  (Gazlay)
# 59639                        Dorian chant (Bill Calhoun)
# 59894      Two Classic Miniatures (71)  (Haydn/Williams)
# 30446                    Voodoo Dance (Elliot Del Borgo)
#
#                                              Selection 3
# 10728                       Knights of Dunvegan  (Meyer)
# 11455                                Quintology  (Meyer)
# 12859               March of Freedom (Robert M. Geisler)
# 13480                          A Hymn for Band  (Stuart)
# 15386                            Medieval Legend (Story)
# ...                                                  ...
# 34426                      Sea Song Trilogy  (McGinty/ )
# 45355                         Dance Celebration  (Smith)
# 59639                          Conviction  (Larry Clark)
# 59894                    Nottingham Castle (12)  (Daehn)
# 30446   The Band in the Square on the Fourth of July ...
#
# [60669 rows x 21 columns]

# %%
# select rows where selection 3 is null
df_clean_selection_3_null = df_clean[df_clean['Selection 3'].isnull()]
df_clean_selection_3_null
# Out:
#                    Event                  School    TEA          City  \
# 700     100-Concert Band                       0   TEA:
# 669     100-Concert Band                       0   TEA:
# 1978    100-Concert Band                       0   TEA:
# 1854    100-Concert Band                       0   TEA:
# 994     100-Concert Band                       0   TEA:
# ...                  ...                     ...    ...           ...
# 27352   100-Concert Band     Del Rio High School   TEA:       Del Rio
# 30444   100-Concert Band             Alvarado MS   TEA:      Alvarado
# 30443   100-Concert Band             Alvarado MS   TEA:      Alvarado
# 27506   100-Concert Band   Stinson Middle School   TEA:   San Antonio
# 30950   100-Concert Band     Del Rio High School   TEA:       Del Rio
#
#                           Directors        Conference Classification    Year  \
# 700                           cathy          Varsity            2005   11109
# 669                 Mandi McCasland          Varsity            2005   11197
# 1978                     lflisowski          Varsity            2005   12205
# 1854                      sbostwick      Non-Varsity            2005   12811
# 994                          cjcain          Varsity            2005   13014
# ...                             ...               ...            ...     ...
# 27352                  Daniel White  Sub Non-Varsity            2014   92973
# 30444       Kelli Bahner / Joe Gunn      Non-Varsity            2014   92415
# 30443       Kelli Bahner / Joe Gunn          Varsity            2014   92418
# 27506   Kevin Leman / Alex Melendez      Non-Varsity            2014   95724
# 30950                  Daniel White      Non-Varsity            2015  104122
#
#       ID Stage Judge 1  ... Stage Judge 3 Stage Final SR Judge 1 SR Judge 2  \
# 700    1             1  ...             1           1          1          1
# 669                     ...
# 1978   1             1  ...             1           2          2          2
# 1854   4             4  ...             4           4          4          4
# 994    2             2  ...             2           1          1          1
# ...   ..           ...  ...           ...         ...        ...        ...
# 27352  1             1  ...             1           1          2          1
# 30444  1             1  ...             1           2          2          2
# 30443  1             1  ...             1           1          1          1
# 27506  1             1  ...             1           1          1          1
# 30950  1             2  ...             2           1          1          1
#
#       SR Judge 3 SR Final                                        Award  \
# 700            1      TRC                       Escapada (David Moore)
# 669                                           Valdres (Hannsen/Curnow)
# 1978           2      RM1       War March of the Tartars (King, K. L.)
# 1854           4        -       Blue Ribbon March (Feldstein-O'Reilly)
# 994            1      RM1                     Newcastle March (Vinson)
# ...          ...      ...                                          ...
# 27352          1        C                     Broken Bow  (Strommen/ )
# 30444          2        2                        Ghost Ship  (Story/ )
# 30443          1        C             Fields of Clover  (Standridge/ )
# 27506          1        D                  Forward March (Paul Murtha)
# 30950          1        2   El Capitan (J.P.Sousa/K.Brion, L.Schissel)
#
#                                   Selection 1  \
# 700             Whitewater Festival (Shaffer)
# 669        Down Longford Way (Grainger/Osmon)
# 1978     Shepherd's Hey (Grainger/Rogers/Mas)
# 1854               Sea Song Trilogy (McGinty)
# 994       The Battle Pavane (Susato/Margolis)
# ...                                       ...
# 27352                   Steel  (Standridge/ )
# 30444   Courtlandt County Festival  (Owens/ )
# 30443                     Accolade  (Himes/ )
# 27506                      Fortis  (Gazlay/ )
# 30950                Ghost Fleet  (Sheldon/ )
#
#                                              Selection 2 Selection 3
# 700                         Declaration Overture (Smith)         NaN
# 669                            Signature (Van der Roost)         NaN
# 1978    Divertimento for Symphonic Winds and Percussi...         NaN
# 1854                      Two Minute Symphony (Margolis)         NaN
# 994                           Distant Horizons (Sweeney)         NaN
# ...                                                  ...         ...
# 27352                   Bonds of Unity (King/Swearingen)         NaN
# 30444                             Forward March (Murtha)         NaN
# 30443   The Band in the Square on the Fourth of July ...         NaN
# 27506                       Dance Celebration  (Smith/ )         NaN
# 30950                 Deir in De (Anon. or Trad./Barker)         NaN
#
# [178 rows x 21 columns]

# %%
df_clean_selection_3_null['Selection 3'] = df_clean_selection_3_null['Selection 2']
df_clean_selection_3_null['Selection 2'] = df_clean_selection_3_null['Selection 1']
df_clean_selection_3_null['Selection 1'] = df_clean_selection_3_null['Award']
df_clean_selection_3_null['Award'] = df_clean_selection_3_null['SR Final']
df_clean_selection_3_null['SR Final'] = df_clean_selection_3_null['SR Judge 3']
df_clean_selection_3_null['SR Judge 3'] = df_clean_selection_3_null['SR Judge 2']
df_clean_selection_3_null['SR Judge 2'] = df_clean_selection_3_null['SR Judge 1']
df_clean_selection_3_null['SR Judge 1'] = df_clean_selection_3_null['Stage Final']
df_clean_selection_3_null['Stage Final'] = df_clean_selection_3_null['Stage Judge 3']
df_clean_selection_3_null['Stage Judge 3'] = df_clean_selection_3_null['Stage Judge 2']
df_clean_selection_3_null['Stage Judge 2'] = df_clean_selection_3_null['Stage Judge 1']
df_clean_selection_3_null['Stage Judge 1'] = df_clean_selection_3_null['ID']
df_clean_selection_3_null['ID'] = df_clean_selection_3_null['Year']
df_clean_selection_3_null['Year'] = df_clean_selection_3_null['Classification']
df_clean_selection_3_null['Classification'] = None
# Out:
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 3'] = df_clean_selection_3_null['Selection 2']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 2'] = df_clean_selection_3_null['Selection 1']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 1'] = df_clean_selection_3_null['Award']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Award'] = df_clean_selection_3_null['SR Final']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Final'] = df_clean_selection_3_null['SR Judge 3']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 3'] = df_clean_selection_3_null['SR Judge 2']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 2'] = df_clean_selection_3_null['SR Judge 1']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 1'] = df_clean_selection_3_null['Stage Final']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Final'] = df_clean_selection_3_null['Stage Judge 3']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 3'] = df_clean_selection_3_null['Stage Judge 2']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 2'] = df_clean_selection_3_null['Stage Judge 1']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 1'] = df_clean_selection_3_null['ID']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['ID'] = df_clean_selection_3_null['Year']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Year'] = df_clean_selection_3_null['Classification']
# C:\Users\macdk\AppData\Local\Temp\ipykernel_7672\3267504115.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Classification'] = None

# %% [markdown]
# ## Combine cleaned rows and export full output to CSV

# %%
# drop df_clean rows where selection 3 is null
df_clean = df_clean[df_clean['Selection 3'].isnull() == False]

# add df_clean_selection_3_null to df_clean
df_clean = pd.concat([df_clean, df_clean_selection_3_null], ignore_index=True)

# Make df_clean column integers
df_clean['Year'] = df_clean['Year'].astype(int)

# sort df_clean by year
df_clean.sort_values(by=['Year'], inplace=True)

# convert to csv
df_clean.to_csv("full_output.csv")

# %%
# Select all 'Selection 1' rows as a list
selection_1_list = df_clean['Selection 1'].tolist()
# Select all 'Selection 2' rows
selection_2_list = df_clean['Selection 2'].tolist()
# Select all 'Selection 3' rows
selection_3_list = df_clean['Selection 3'].tolist()

# combine selection 1, 2, and 3 into one list
selection_list = selection_1_list + selection_2_list + selection_3_list

# convert list to dataframe
selection_df = pd.DataFrame(selection_list)
selection_df.columns = ['Selection']

# count the number of times each selection appears in selection_list
selection_count = selection_df['Selection'].value_counts()
selection_count
# Out:
#  Dance Celebration  (Smith)                                         776
#  Moscow, 1941  (Balmages)                                           687
#  Colliding Visions  (Balmages/ )                                    681
#  Atlantis  (McGinty)                                                639
#  Pinnacle  (Grice)                                                  592
#                                                                    ...
#  The Trombone King (Karl King, arr. John P. Painter)                  1
#  Children's March "Over the Hills and Far Away" (Percy Grainger)      1
#  Discovery March (John Edmundson)                                     1
#  Mr. Bartow (Larry Clark)                                             1
#  Fidelity March (K.L. King/Milford)                                   1
# Name: Selection, Length: 31209, dtype: int64

# %% [markdown]
# # Get the full PML list to CSV

# %%
# import all of the pml csv files into a dataframe
files = glob.glob("pml/*.csv")
pml_df = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)
# conver pml_df to csv
pml_df.to_csv("pml_output.csv")
