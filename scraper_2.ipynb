# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import numpy as np
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt

# %%
# set up the driver
service = ChromeService(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome("/Users/macdkw/Downloads/chromedriver")

# Navigate to the page
def home():
    driver.get("https://www.texasmusicforms.com/csrrptUILpublic.asp")

# get results button function
def click_results_button():
    get_results_button = driver.find_element(by=By.CLASS_NAME, value="btn-success")
    get_results_button.click()


# "Search again" button function
def click_search_button():
    search_again_button = driver.find_element(by=By.NAME, value="chan")
    search_again_button.click()
    driver.implicitly_wait(10)

# find the drop down menus and fill them out
def form_completer(year, region, contest_item):
    year_menu = driver.find_element(by=By.NAME, value="yr")
    region_menu = driver.find_element(by=By.NAME, value="reg")
    event_menu = driver.find_element(by=By.NAME, value="ev")
    year_menu.send_keys(year)
    region_menu.send_keys(f"Region {region}")
    event_menu.send_keys("Band")

    # find the hidden drop down menu, and collect its contents
    contest_menu = driver.find_element(by=By.NAME, value="cn")
    contest_menu_contents = contest_menu.find_elements(by=By.TAG_NAME, value="option")
    contest_menu_length = len(contest_menu_contents)
    contest_menu.send_keys(contest_menu_contents[contest_item].text)


# scrape the data
def scraper_loop():
    # make sure that were seeing all results, not just the top 20
    show_all_button = driver.find_element(by=By.NAME, value="DataTables_Table_0_length")
    show_all_button.send_keys("All")
    # get the table
    table = driver.find_elements(by=By.TAG_NAME, value="tbody")[1]
    table_rows = table.find_elements(by=By.TAG_NAME, value="tr")
    # loop through table contents
    for row in table_rows:
        cells = row.find_elements(by=By.TAG_NAME, value="td")
        column_content = []
        for cell in cells:
            cell_content_full = cell.text
            cell_content = cell_content_full.split("\n")
            for i in cell_content:
                column_content.append(i)
            #column_content.append(cell_content)
        row_content.append(column_content)

# convert to dataframe
def convert_to_dataframe():
    df = pd.DataFrame(row_content)
    if len(df.columns) == 21:
        df.columns = columns_21
    elif len(df.columns) == 22:
        df.columns = columns_22
    # export to csv
    df.to_csv(f"full_run/texas_music_forms_{year}_{region}_{contest_item}_band.csv")

columns_21 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3']

columns_22 = ['Event', 'School', 'TEA', 'City', 'Directors', 'Conference', 'Classification', 'Year', 'ID', 
    'Stage Judge 1', 'Stage Judge 2', 'Stage Judge 3', 'Stage Final', 
    'SR Judge 1', 'SR Judge 2', 'SR Judge 3', 'SR Final', 'Award', 
    'Selection 1', 'Selection 2', 'Selection 3', 'oops']

row_content = []

# Define year and region variables
year = 2017
region = 0

for y in range(2019, 2023):
    for r in range(0, 33):
        try:
            contest_item = 1
            region = region + 1
            for i in range(1, 15):
                try:
                    home()
                    form_completer(year, region, contest_item)
                    click_results_button()
                    scraper_loop()
                    convert_to_dataframe()
                    contest_item = contest_item + 1
                    row_content = []
                except:
                    print(f"{year}, {region}, {contest_item}")
                    break
        except:
            break
    year = year + 1
    region = 0

# %%
# setting the path for joining multiple files
files = os.path.join("/Users/macdkw/Class/uil_results/full_run/", "*.csv")

# list of merged files returned
files = glob.glob(files)

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df = pd.DataFrame(df)

# drop unnamed column
df.drop(columns=['Unnamed: 0'], inplace=True)

# select rows with acc column 
oops_df = df[df['oops'].notnull()]

# delete the acc columns and fix column names
oops_fix_df = oops_df.drop(columns=['Conference'])
oops_fix_df.columns = columns_21

# drop acc rows from df
df = df.loc[df['oops'].isnull() == True]

# add fixed df to df
df = pd.concat([df, oops_fix_df], ignore_index=True)

# drop oops column
df.drop(columns=['oops'], inplace=True)

df.tail()
# Out:
#                    Event                   School    TEA          City  \
# 60664   100-Concert Band            LJ: Garcia MS   TEA:       Mission
# 60665   100-Concert Band    Southwest High School   TEA:   San Antonio
# 60666   100-Concert Band    Southwest High School   TEA:   San Antonio
# 60667   100-Concert Band        Terry High School   TEA:     Rosenberg
# 60668   100-Concert Band   Centennial High School   TEA:      Burleson
#
#                                                Directors Conference  \
# 60664                                Ramiro Garza / None         CC
# 60665      Gabriel Perez / Natalie Ball, Patrick Aguirre      AAAAA
# 60666      Patrick Aguirre / Natalie Ball, Gabriel Perez      AAAAA
# 60667     Tim Taylor / Rachel Castillo and Brian Allmond      AAAAA
# 60668   Philip Jones / Richard Kearns, Shawn Murphy, ...      AAAAA
#
#           Classification  Year      ID Stage Judge 1  ... Stage Judge 3  \
# 60664           Varsity   2012   69829             2  ...             1
# 60665  Sub Non-Varsity A  2020  158077                ...
# 60666      Non-Varsity A  2020  158069                ...
# 60667           Varsity   2016  115375             1  ...             2
# 60668   Sub Non-Varsity   2017  128106             2  ...             2
#
#       Stage Final SR Judge 1 SR Judge 2 SR Judge 3 SR Final Award  \
# 60664           1          2          2          2        2     2
# 60665
# 60666
# 60667           2          2          1          1        1     1
# 60668           2          2          2          2        2
#
#                                              Selection 1  \
# 60664                      The Big Circus March (Foster)
# 60665                   Eclipse Galop (King Arr. Glover)
# 60666                       Tahoka Galop (William Owens)
# 60667   Manhattan Beach March (John Philip Sousa/Fred...
# 60668                Valley Forge March (John Edmondson)
#
#                                              Selection 2  \
# 60664                                    Crusade (Gassi)
# 60665   Scenes from the American West (21581) (play a...
# 60666                         Benediction (John Stevens)
# 60667                 The Hounds of Spring (Alfred Reed)
# 60668                      Colliding Visions  (Balmages)
#
#                                              Selection 3
# 60664                        Knights of Dunvegan (Meyer)
# 60665                Armenian Rhapsody (20761)  (Vinson)
# 60666                                 Viva! (Jack Wilds)
# 60667   Kilimanjaro: An African Portrait (Robert Wash...
# 60668                                  Mythos (Bernotas)
#
# [5 rows x 21 columns]

# %%
# drop duplicate rows
df_clean = df
df_clean.drop_duplicates(keep='first', inplace=True)
df_clean.sort_values(by=['Classification', 'Year'], inplace=True)
df_clean
# Out:
#                    Event                       School               TEA  \
# 14433   100-Concert Band         Progreso High School              TEA:
# 17136   100-Concert Band                     Bangs HS              TEA:
# 24128   100-Concert Band               Woodville High              TEA:
# 44305   100-Concert Band         New Deal High School              TEA:
# 8245    100-Concert Band             Alicia R. Chacon              TEA:
# ...                  ...                          ...               ...
# 45107   100-Concert Band    Warren Junior High School              TEA:
# 59063   100-Concert Band                   McCamey MS              TEA:
# 10009   100-Concert Band   Lake Air Montessori Magnet       TEA: 161914
# 23172   100-Concert Band                    Alpine MS   TEA: 022 901041
# 52318   100-Concert Band                     Eastland              TEA:
#
#              City                                      Directors Conference  \
# 14433    Progreso                                    James Yates        AAA
# 17136       Bangs                 Tommy Perkins / Charla Bretzke         AA
# 24128   Woodville                                      Lou Ellis         AA
# 44305    New Deal                        James Nance / Kay Nance          A
# 8245      El Paso   Jose Barriga / Salvador Melendez, Louie Nava          C
# ...           ...                                            ...        ...
# 45107      Warren                  Carl Hooper / Russell Hopkins        AAA
# 59063     McCamey                  Shawna Torres / German Torres          C
# 10009        Waco           Todd Modgling / Stephanie Fernihough          C
# 23172      Alpine                                    Marina Azar          C
# 52318    Eastland    Stephen Cox / Terry Everts, Dillon Phillips         AA
#
#       Classification  Year      ID Stage Judge 1  ... Stage Judge 3  \
# 14433                 2009   48134             3  ...             2
# 17136                 2009   43637             1  ...             1
# 24128                 2009   46343             2  ...             2
# 44305                 2009   45190             2  ...             1
# 8245                  2010   59515             1  ...             1
# ...              ...   ...     ...           ...  ...           ...
# 45107      Varsity C  2016  116407             4  ...             4
# 59063      Varsity C  2018  129652             2  ...             2
# 10009      Varsity C  2022  175313             2  ...             1
# 23172      Varsity C  2022  172064             1  ...             1
# 52318      Varsity C  2014   91726             2  ...             2
#
#       Stage Final SR Judge 1 SR Judge 2 SR Judge 3 SR Final Award  \
# 14433           2          2          2          2        2
# 17136           1          1          1          1        1     A
# 24128           2          1          1          1        1     1
# 44305           2          1          1          1        1     1
# 8245            1          2          1          1        1     C
# ...           ...        ...        ...        ...      ...   ...
# 45107           4          2          1          1        1     2
# 59063           2          1          2          1        1     2
# 10009           2          1          2          1        1     2
# 23172           1          1          1          1        1     C
# 52318           2          1          2          1        1     2
#
#                                            Selection 1  \
# 14433                    Portrait of a Clown (Ticheli)
# 17136                        Monterey March (LaPlante)
# 24128   Under The Double Eagle - March (Wagner/Glover)
# 44305                 La Fiesta Brava (John Edmondson)
# 8245                       Lexington March (Edmondson)
# ...                                                ...
# 45107             Swashbuckler's march (Mark Williams)
# 59063                      Forward March (Paul Murtha)
# 10009             Spirit of America March (Ken Harris)
# 23172               Independentia March (Matt Conaway)
# 52318         The Big Circus March ( Robert E. Foster)
#
#                                              Selection 2  \
# 14433                                Prospect (La Plant)
# 17136   Two British Folk Songs  (Anon. or Trad./Del B...
# 24128                      A Childhood Hymn  (Holsinger)
# 44305                       Cumberland Cross  (Strommen)
# 8245                           Voodoo Dance  (del Borgo)
# ...                                                  ...
# 45107              Courtlandt County Festival  (Owens/ )
# 59063                                Majestica  (Gazlay)
# 10009      Two Classic Miniatures (71)  (Haydn/Williams)
# 23172                        Dorian chant (Bill Calhoun)
# 52318                    Voodoo Dance (Elliot Del Borgo)
#
#                                              Selection 3
# 14433               March of Freedom (Robert M. Geisler)
# 17136                          A Hymn for Band  (Stuart)
# 24128                       Knights of Dunvegan  (Meyer)
# 44305                                Quintology  (Meyer)
# 8245                             Medieval Legend (Story)
# ...                                                  ...
# 45107                      Sea Song Trilogy  (McGinty/ )
# 59063                         Dance Celebration  (Smith)
# 10009                    Nottingham Castle (12)  (Daehn)
# 23172                          Conviction  (Larry Clark)
# 52318   The Band in the Square on the Fourth of July ...
#
# [60669 rows x 21 columns]

# %%
# select rows where selection 3 is null
df_clean_selection_3_null = df_clean[df_clean['Selection 3'].isnull()]
df_clean_selection_3_null

df_clean_selection_3_null['Selection 3'] = df_clean_selection_3_null['Selection 2']
df_clean_selection_3_null['Selection 2'] = df_clean_selection_3_null['Selection 1']
df_clean_selection_3_null['Selection 1'] = df_clean_selection_3_null['Award']
df_clean_selection_3_null['Award'] = df_clean_selection_3_null['SR Final']
df_clean_selection_3_null['SR Final'] = df_clean_selection_3_null['SR Judge 3']
df_clean_selection_3_null['SR Judge 3'] = df_clean_selection_3_null['SR Judge 2']
df_clean_selection_3_null['SR Judge 2'] = df_clean_selection_3_null['SR Judge 1']
df_clean_selection_3_null['SR Judge 1'] = df_clean_selection_3_null['Stage Final']
df_clean_selection_3_null['Stage Final'] = df_clean_selection_3_null['Stage Judge 3']
df_clean_selection_3_null['Stage Judge 3'] = df_clean_selection_3_null['Stage Judge 2']
df_clean_selection_3_null['Stage Judge 2'] = df_clean_selection_3_null['Stage Judge 1']
df_clean_selection_3_null['Stage Judge 1'] = df_clean_selection_3_null['Conference']
df_clean_selection_3_null['ID'] = df_clean_selection_3_null['Year']
df_clean_selection_3_null['Year'] = df_clean_selection_3_null['Classification']
# make classification column nan
df_clean_selection_3_null['Classification'] = np.nan

df_clean_selection_3_null
# Out:
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 3'] = df_clean_selection_3_null['Selection 2']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 2'] = df_clean_selection_3_null['Selection 1']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Selection 1'] = df_clean_selection_3_null['Award']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Award'] = df_clean_selection_3_null['SR Final']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Final'] = df_clean_selection_3_null['SR Judge 3']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 3'] = df_clean_selection_3_null['SR Judge 2']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 2'] = df_clean_selection_3_null['SR Judge 1']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['SR Judge 1'] = df_clean_selection_3_null['Stage Final']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Final'] = df_clean_selection_3_null['Stage Judge 3']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 3'] = df_clean_selection_3_null['Stage Judge 2']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 2'] = df_clean_selection_3_null['Stage Judge 1']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Stage Judge 1'] = df_clean_selection_3_null['Conference']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['ID'] = df_clean_selection_3_null['Year']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Year'] = df_clean_selection_3_null['Classification']
# /var/folders/x1/n3nh_d4s0pbdzprdkd4p75yr0000gn/T/ipykernel_48744/1030540278.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_selection_3_null['Classification'] = np.nan
#                    Event                  School    TEA          City  \
# 13328   100-Concert Band                       0   TEA:
# 13230   100-Concert Band                       0   TEA:
# 9117    100-Concert Band                       0   TEA:
# 26026   100-Concert Band                       0   TEA:
# 37724   100-Concert Band                       0   TEA:
# ...                  ...                     ...    ...           ...
# 43798   100-Concert Band     Del Rio High School   TEA:       Del Rio
# 52316   100-Concert Band             Alvarado MS   TEA:      Alvarado
# 52315   100-Concert Band             Alvarado MS   TEA:      Alvarado
# 25167   100-Concert Band   Stinson Middle School   TEA:   San Antonio
# 20496   100-Concert Band     Del Rio High School   TEA:       Del Rio
#
#                           Directors        Conference  Classification  Year  \
# 13328                         cathy          Varsity              NaN  2005
# 13230               Mandi McCasland          Varsity              NaN  2005
# 9117                     lflisowski          Varsity              NaN  2005
# 26026                     sbostwick      Non-Varsity              NaN  2005
# 37724                        cjcain          Varsity              NaN  2005
# ...                             ...               ...             ...   ...
# 43798                  Daniel White  Sub Non-Varsity              NaN  2014
# 52316       Kelli Bahner / Joe Gunn      Non-Varsity              NaN  2014
# 52315       Kelli Bahner / Joe Gunn          Varsity              NaN  2014
# 25167   Kevin Leman / Alex Melendez      Non-Varsity              NaN  2014
# 20496                  Daniel White      Non-Varsity              NaN  2015
#
#            ID     Stage Judge 1  ... Stage Judge 3 Stage Final SR Judge 1  \
# 13328   11109          Varsity   ...             2           1          1
# 13230   11197          Varsity   ...
# 9117    12205          Varsity   ...             1           1          2
# 26026   12811      Non-Varsity   ...             4           4          4
# 37724   13014          Varsity   ...             1           2          1
# ...       ...               ...  ...           ...         ...        ...
# 43798   92973  Sub Non-Varsity   ...             1           1          1
# 52316   92415      Non-Varsity   ...             3           1          2
# 52315   92418          Varsity   ...             1           1          1
# 25167   95724      Non-Varsity   ...             1           1          1
# 20496  104122      Non-Varsity   ...             2           2          1
#
#       SR Judge 2 SR Judge 3 SR Final Award  \
# 13328          1          1        1   TRC
# 13230
# 9117           2          2        2   RM1
# 26026          4          4        4     -
# 37724          1          1        1   RM1
# ...          ...        ...      ...   ...
# 43798          2          1        1     C
# 52316          2          2        2     2
# 52315          1          1        1     C
# 25167          1          1        1     D
# 20496          1          1        1     2
#
#                                        Selection 1  \
# 13328                       Escapada (David Moore)
# 13230                     Valdres (Hannsen/Curnow)
# 9117        War March of the Tartars (King, K. L.)
# 26026       Blue Ribbon March (Feldstein-O'Reilly)
# 37724                     Newcastle March (Vinson)
# ...                                            ...
# 43798                     Broken Bow  (Strommen/ )
# 52316                        Ghost Ship  (Story/ )
# 52315             Fields of Clover  (Standridge/ )
# 25167                  Forward March (Paul Murtha)
# 20496   El Capitan (J.P.Sousa/K.Brion, L.Schissel)
#
#                                   Selection 2  \
# 13328           Whitewater Festival (Shaffer)
# 13230      Down Longford Way (Grainger/Osmon)
# 9117     Shepherd's Hey (Grainger/Rogers/Mas)
# 26026              Sea Song Trilogy (McGinty)
# 37724     The Battle Pavane (Susato/Margolis)
# ...                                       ...
# 43798                   Steel  (Standridge/ )
# 52316   Courtlandt County Festival  (Owens/ )
# 52315                     Accolade  (Himes/ )
# 25167                      Fortis  (Gazlay/ )
# 20496                Ghost Fleet  (Sheldon/ )
#
#                                              Selection 3
# 13328                       Declaration Overture (Smith)
# 13230                          Signature (Van der Roost)
# 9117    Divertimento for Symphonic Winds and Percussi...
# 26026                     Two Minute Symphony (Margolis)
# 37724                         Distant Horizons (Sweeney)
# ...                                                  ...
# 43798                   Bonds of Unity (King/Swearingen)
# 52316                             Forward March (Murtha)
# 52315   The Band in the Square on the Fourth of July ...
# 25167                       Dance Celebration  (Smith/ )
# 20496                 Deir in De (Anon. or Trad./Barker)
#
# [178 rows x 21 columns]

# %%
# drop df_clean rows where selection 3 is null
df_clean = df_clean[df_clean['Selection 3'].isnull() == False]

# add df_clean_selection_3_null to df_clean
df_clean = pd.concat([df_clean, df_clean_selection_3_null], ignore_index=True)

# Make df_clean column integers
df_clean['Year'] = df_clean['Year'].astype(int)

# sort df_clean by year
df_clean.sort_values(by=['Year'], inplace=True)


# convert to csv
df_clean.to_csv(f"full_output.csv")

df_clean
# Out:
#                    Event                   School               TEA  \
# 0       100-Concert Band     Hemphill High School              TEA:
# 1503    100-Concert Band           Flour Bluff JH              TEA:
# 1502    100-Concert Band              Driscoll MS              TEA:
# 1501    100-Concert Band              Calallen MS              TEA:
# 1500    100-Concert Band                 Blunt MS              TEA:
# ...                  ...                      ...               ...
# 58116   100-Concert Band     Anderson High School    TEA: 227901009
# 58117   100-Concert Band       Dulles High School   TEA: 0799070001
# 58118   100-Concert Band     Eastwood High School    TEA: 071905002
# 58281   100-Concert Band   Heritage Middle School    TEA: 220906043
# 58198   100-Concert Band                Sinton HS     TEA: 205-0906
#
#                   City                                          Directors  \
# 0             Hemphill                                    Evan Richardson
# 1503    Corpus Christi                                      David Burnett
# 1502    Corpus Christi                                         Jon Rimmer
# 1501    Corpus Christi                                   Jeffery Valperts
# 1500      Aransas Pass                                      Daci Fletcher
# ...                ...                                                ...
# 58116           Austin                          Cheryl Lee / Frank Nedley
# 58117       Sugar Land                                         Joe Pruitt
# 58118          El Paso   John A Matthews II / Art Avila Jr., John K. Oman
# 58281      Colleyville                       Joshua Smith / Brenda Hinton
# 58198           Sinton                                      Michael Solis
#
#       Conference Classification  Year      ID Stage Judge 1  ...  \
# 0             AA       Varsity   2005   18178             1  ...
# 1503         CCC   Non-Varsity   2005   11875             1  ...
# 1502          CC   Non-Varsity   2005   12215             3  ...
# 1501          CC   Non-Varsity   2005   12099             2  ...
# 1500          CC   Non-Varsity   2005   12116             4  ...
# ...          ...            ...   ...     ...           ...  ...
# 58116      AAAAA       Varsity   2022  174142             1  ...
# 58117     AAAAAA       Varsity   2022  177751             1  ...
# 58118     AAAAAA       Varsity   2022  177354             2  ...
# 58281         CC       Varsity   2022  176705             1  ...
# 58198       AAAA   Non-Varsity   2022  175570             1  ...
#
#       Stage Judge 3 Stage Final SR Judge 1 SR Judge 2 SR Judge 3 SR Final  \
# 0                 1           1          2          1          1        1
# 1503              1           1          1          1          2        1
# 1502              3           3          3          3          4        3
# 1501              1           1          2          2          1        2
# 1500              4           4          4          4          4        4
# ...             ...         ...        ...        ...        ...      ...
# 58116             1           1          1          1          1        1
# 58117             1           1          1          1          1        1
# 58118             2           2          1          1          1        1
# 58281             1           1          1          1          1        1
# 58198             1           1          2          2          2        2
#
#       Award                                        Selection 1  \
# 0       T A                             The Huntress (KL King)
# 1503    SWD        March of the Palace Guards (Jerry Williams)
# 1502                          March of the Cyclops (Henderson)
# 1501     P2           March of the Cyclops (Kenneth Henderson)
# 1500                            Two Minute Symphony (Margolis)
# ...     ...                                                ...
# 58116     A               Symphonic Movement (546)  (Nelhybel)
# 58117     A   Joyce''s 71st New York Regimental March (Thor...
# 58118     1                 An American Elegy (416)  (Ticheli)
# 58281     C              St. Petersburg March (Johnnie Vinson)
# 58198     2                         We the People (Swearingen)
#
#                                           Selection 2  \
# 0               In The Shining Of The Stars (Sheldon)
# 1503         Two British Folk Songs (Del Borgo (arr))
# 1502                               Atlantis (McGinty)
# 1501    Chester (Billings/Tolmage/Staff Osterling/HL)
# 1500                        Amazing Grace (Edmondson)
# ...                                               ...
# 58116                    Sheltering Sky (John Mackey)
# 58117       Noisy Wheels of Joy (747) (Eric Whitacre)
# 58118                            Ride (15843)  (Hazo)
# 58281             Sketches of Canada (19608) (Story/)
# 58198    In The Bleak Midwinter (34)  (Holst/Bullock)
#
#                                              Selection 3
# 0                        The Battle of Jericho (Spinney)
# 1503                                    Pinnacle (Grice)
# 1502                          Liturgical Fanfare (Smith)
# 1501                            Phantom Ship (Del Borgo)
# 1500                   King Willams March (Clark/Balent)
# ...                                                  ...
# 58116   Entry March of the Boyars (Johan Halvorsen/ed...
# 58117   Elsas Procession to the Cathedral (615) (Rich...
# 58118                Crossed Sabers (Charles Booker, Jr)
# 58281                Into the Arctic (20710) (Balmages/)
# 58198                      Expectations (19603)  (Clark)
#
# [60847 rows x 21 columns]

# %%
# count values for year
year_count = df_clean['Year'].value_counts()
year_count.head(30)
# Out:
# 2019    4015
# 2018    4011
# 2020    3990
# 2022    3924
# 2016    3807
# 2017    3790
# 2015    3603
# 2014    3602
# 2012    3468
# 2013    3425
# 2011    3409
# 2010    3265
# 2009    3121
# 2007    2860
# 2006    2856
# 2008    2751
# 2021    2568
# 2005    2204
# Name: Year, dtype: int64

# %%
# Select all 'Selection 1' rows as a list
selection_1_list = df_clean['Selection 1'].tolist()
# Select all 'Selection 2' rows
selection_2_list = df_clean['Selection 2'].tolist()
# Select all 'Selection 3' rows
selection_3_list = df_clean['Selection 3'].tolist()

# combine selection 1, 2, and 3 into one list
selection_list = selection_1_list + selection_2_list + selection_3_list

# convert list to dataframe
selection_df = pd.DataFrame(selection_list)
selection_df.columns = ['Selection']

# count the number of times each selection appears in selection_list
selection_count = selection_df['Selection'].value_counts()
selection_count
# Out:
#  Dance Celebration  (Smith)                  776
#  Moscow, 1941  (Balmages)                    687
#  Colliding Visions  (Balmages/ )             681
#  Atlantis  (McGinty)                         639
#  Pinnacle  (Grice)                           592
#                                             ...
#  Monterey March (Pierre La PLante)             1
#  The Big Circus March (Robert E. Foster )      1
#  Norland MArch (John Edmondson)                1
#  Aces of The Air (Karl King/Swearingen)        1
#  Symphonic Overture (94)  (Carter)             1
# Name: Selection, Length: 31209, dtype: int64
